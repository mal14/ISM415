# %%
import pandas as pd

# %%
data = pd.read_csv('IMDB-Movie-Data.csv')

# %%
data.head(50)
# Out:
#     Rank                                        Title  \
# 0      1                      Guardians of the Galaxy
# 1      2                                   Prometheus
# 2      3                                        Split
# 3      4                                         Sing
# 4      5                                Suicide Squad
# 5      6                               The Great Wall
# 6      7                                   La La Land
# 7      8                                     Mindhorn
# 8      9                           The Lost City of Z
# 9     10                                   Passengers
# 10    11      Fantastic Beasts and Where to Find Them
# 11    12                               Hidden Figures
# 12    13                                    Rogue One
# 13    14                                        Moana
# 14    15                                     Colossal
# 15    16                      The Secret Life of Pets
# ...

# %%
data.tail(50)
# Out:
#      Rank                                        Title  \
# 926   927                                     Precious
# 927   928                             The Sea of Trees
# 930   931                                    Footloose
# 931   932                                    If I Stay
# 934   935                               The Love Witch
# 935   936  Talladega Nights: The Ballad of Ricky Bobby
# 936   937         The Human Centipede (First Sequence)
# 937   938                                        Super
# 940   941                      The Midnight Meat Train
# 941   942                   The Twilight Saga: Eclipse
# 943   944                          What's Your Number?
# 944   945                                      Riddick
# 947   948                                   King Cobra
# 948   949                                  After Earth
# 949   950                                        Kicks
# 950   951               Me and Earl and the Dying Girl
# ...

# %% [markdown]
# ## cleaning the data

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.dropna(how ='any' , inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# ## indexing by title,genre and year

# %%
data[['Title', 'Genre', 'Year']]
# Out:
#                         Title                     Genre  \
# 0     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                  Prometheus  Adventure,Mystery,Sci-Fi
# 2                       Split           Horror,Thriller
# 3                        Sing   Animation,Comedy,Family
# 4               Suicide Squad  Action,Adventure,Fantasy
# ..                        ...                       ...
# 993  Resident Evil: Afterlife   Action,Adventure,Horror
# 994                 Project X                    Comedy
# 996           Hostel: Part II                    Horror
# 997    Step Up 2: The Streets       Drama,Music,Romance
# 999                Nine Lives     Comedy,Family,Fantasy
#
#                              Year
# 0   1970-01-01 00:00:00.000002014
# 1   1970-01-01 00:00:00.000002012
# 2   1970-01-01 00:00:00.000002016
# 3   1970-01-01 00:00:00.000002016
# 4   1970-01-01 00:00:00.000002016
# ..                            ...
# 993 1970-01-01 00:00:00.000002010
# ...

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...
